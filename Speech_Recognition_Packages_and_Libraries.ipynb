# %% [markdown]
# <a href="https://colab.research.google.com/github/iamab3/Basics-of-Speech-Recognition/blob/main/Speech_Recognition_Packages_and_Libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing packages for Speech Recognition

# %%
# Install librosa for music and speech analysis. It extracts important features and perform various transformations and visualisations
# !pip install librosa
# Install SpeechRecognition to convert speech into written text
# !pip install SpeechRecognition
# Install jiwer to evaluate the performance of speech recognition systems
# !pip install jiwer
# !pip install matplotlib
# Install gTTS - google text to speech library
# !pip install gTTS

# %%
# Install Whisper from OpenAI
# First install Pytorch - https://pytorch.org/get-started/locally/ - Use this link to get the command prompt
# !pip install torch torchvision
# Install Chocolatey (Windows) or Homebrew (Mac)
# Run below Windows Package Manager - "Run as Admin" (Windows) or in Terminal for Mac
'''
Set-ExecutionPolicy Bypass -Scope Process -Force; [System.Net.ServicePointManager]::SecurityProtocol = [System.Net.ServicePointManager]::SecurityProtocol -bor 3072; iex ((New-Object System.Net.WebClient).DownloadString('https://community.chocolatey.org/install.ps1'))
'''
# To handle different audio file formats
'''
choco install ffmpeg

# Choose 'yes' when prompted
'''

# Install whisper
# !pip install -U openai-whisper

# To check if the correct package has been installed
# !pip show openai-whisper

# %% [markdown]
# Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

#Library for audio analysis
import librosa
import librosa.display
import soundfile as sf
import speech_recognition as sr

from jiwer import wer, cer
from IPython.display import Audio

import whisper

import csv
import os
import tempfile
import wave

from gtts import gTTS
